# %%
pwd
# Out:
# 'C:\\Users\\Asus\\Desktop\\problem solving & prorgamming'

# %% [markdown]
# ### Load Data Set

# %%
import pandas as pd
filepath ='datafiles/IRIS.csv'
def readCsvData(filepath):
    return pd.read_csv(filepath)
df = readCsvData(filepath)
#print(df)

# %% [markdown]
# ### Summarize the Dataset

# %%
df.columns.tolist()
# Out:
# ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'species']

# %%
# Shape
df.shape
# Out:
# (150, 5)

# %%
# Head
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
# Tail
df.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
df.iloc[1:4]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa

# %%
# Class distribution
df['species'].value_counts()
# Out:
# Iris-versicolor    50
# Iris-setosa        50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
# Data Types for each attribute
print(df.dtypes)
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
# sepal_length    150 non-null float64
# sepal_width     150 non-null float64
# petal_length    150 non-null float64
# petal_width     150 non-null float64
# species         150 non-null object
# dtypes: float64(4), object(1)
# memory usage: 5.9+ KB

# %% [markdown]
# ### Statistical Summary

# %%
# Descriptions
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Pearson Correlations
correlation = df.corr(method='pearson')
print(correlation)
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
# Skew for each attribute
skew = df.skew()
print(skew)
# Out:
# sepal_length    0.314911
# sepal_width     0.334053
# petal_length   -0.274464
# petal_width    -0.104997
# dtype: float64

# %% [markdown]
# ### Data Visualization

# %%
# Box and Whisker plots
from matplotlib import pyplot
df.plot(kind='box',subplots=True,layout=(2,2),sharex=False,sharey=False)
pyplot.show()

# %%
# Density plots
from matplotlib import pyplot
df.plot(kind='density',subplots=True,layout=(2,2),sharex=False,sharey=False)
pyplot.show()

# %%
# Histrogram
from matplotlib import pyplot
df.hist()
pyplot.show()

# %%
# Scatter plot matrix
from matplotlib import pyplot
from pandas.plotting import scatter_matrix
scatter_matrix(df)
pyplot.show()

# %%
import seaborn as sns
sns.pairplot(df,hue='species',height=2)

# %%
sns.heatmap(df.corr())

# %%
import numpy as np
sns.set(color_codes=True)
import pandas as pd
# %matplotlib inline
# violinplots on petal-length for each species
sns.violinplot(data=df,x="species", y="petal_length")

# %%
# violinplots on petal-length for each species
sns.violinplot(data=df,x="species", y="petal_width")

# %%
# violinplots on sepal-length for each species
sns.violinplot(data=df,x="species", y="sepal_length")

# %%
# violinplots on sepal-length for each species
sns.violinplot(data=df,x="species", y="sepal_width")

# %%
fig = df[df['species'] == 'Iris-setosa'].plot(kind='density', x='sepal_length', y='sepal_width', color='orange', label='Setosa')
df[df['species'] == 'Iris-versicolor'].plot(kind='density', x='sepal_length', y='sepal_width', color='yellow', label='Versicolor', ax=fig)
df[df['species'] == 'Iris-virginica'].plot(kind='density', x='sepal_length', y='sepal_width', color='blue', label='Verginica', ax=fig)
fig.set_ylabel('Sepal Width')
fig.set_xlabel('Sepal Length')
fig.set_title('Sepal Length vs Width')
fig = plt.gcf()
fig.set_size_inches(5,5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9d6041443109> in <module>
#       5 fig.set_xlabel('Sepal Length')
#       6 fig.set_title('Sepal Length vs Width')
# ----> 7 fig = plt.gcf()
#       8 fig.set_size_inches(5,5)
#       9 plt.show()
#
# NameError: name 'plt' is not defined

# %%
fig = df[df['species'] == 'Iris-setosa'].plot(kind='density', x='petal_length', y='petal_width', color='red', label='Setosa')
df[df['species'] == 'Iris-versicolor'].plot(kind='density', x='petal_length', y='petal_width', color='black', label='Versicolor', ax=fig)
df[df['species'] == 'Iris-virginica'].plot(kind='density', x='petal_length', y='petal_width', color='blue', label='Verginica', ax=fig)
fig.set_ylabel('petal Width')
fig.set_xlabel('petal Length')
fig.set_title('petal Length vs Width')
fig = plt.gcf()
fig.set_size_inches(5, 5)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-7c7eb1d251a4> in <module>
#       5 fig.set_xlabel('petal Length')
#       6 fig.set_title('petal Length vs Width')
# ----> 7 fig = plt.gcf()
#       8 fig.set_size_inches(5, 5)
#       9 plt.show()
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### Create a Validate Dataset

# %%
# Split-out validation dataset
from sklearn.model_selection import train_test_split
array = df.values
X = array[:,0:4]
Y = array[:,4]
validation_size = 0.2
seed = 7
X_train,X_validation,Y_train,Y_validation = train_test_split(X,Y,test_size=validation_size, random_state=seed)

# %% [markdown]
# ### Evaluate some Algorithms
# - Linear Machine learning algorithm
#     - Logistic Regression (LR)
#     - Linear Discriminant Analysis (LDA)
# - NonLinear Machine learning algorithm
#     - K-Nearest Neighbors (KNN)
#     - Classification and Regression Tree (CART)
#     - Gaussian Naive Bayes (NB)
#     - Support Vector Machines (SVM)

# %%
# Load Libraries
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier 
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### Select the best model

# %%
# Spot check algorithms
models = []
models.append(('LR',LogisticRegression()))
models.append(('LDA',LinearDiscriminantAnalysis()))
models.append(('KNN',KNeighborsClassifier()))
models.append(('CART',DecisionTreeClassifier()))
models.append(('NB',GaussianNB()))
models.append(('SVM',SVC()))
# evaluate each model in turn
results = []
names = []
for name,model in models:
    kfold = KFold(n_splits=10,random_state=seed)
    cv_results = cross_val_score(model,X_train,Y_train,cv=kfold,scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name,cv_results.mean(),cv_results.std())
    print(msg)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# ...

# %%
# Compare algorithm
from matplotlib import pyplot
fig = pyplot.figure()
fig = suptitle('Algorithm comparison')
ax = fig.add_subplot(111)
pyplot.boxplot(results)
ax.set_xticklabels(names)
pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-23326daf46cd> in <module>
#       2 from matplotlib import pyplot
#       3 fig = pyplot.figure()
# ----> 4 fig = suptitle('Algorithm comparison')
#       5 ax = fig.add_subplot(111)
#       6 pyplot.boxplot(results)
#
# NameError: name 'suptitle' is not defined

# %% [markdown]
# ### Make predictions

# %%
# Make prededictions on validation dataset
knn = KNeighborsClassifier()
knn.fit(X_train,Y_train)
predictions = knn.predict(X_validation)
print(accuracy_score(Y_validation,predictions))
print(confusion_matrix(Y_validation,predictions))
print(classification_report(Y_validation,predictions))
# Out:
# 0.9
# [[ 7  0  0]
#  [ 0 11  1]
#  [ 0  2  9]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         7
# Iris-versicolor       0.85      0.92      0.88        12
#  Iris-virginica       0.90      0.82      0.86        11
#
#        accuracy                           0.90        30
#       macro avg       0.92      0.91      0.91        30
#    weighted avg       0.90      0.90      0.90        30

# %%
svm = SVC()
svm.fit(X_train,Y_train)
predictions = svm.predict(X_validation)
print(accuracy_score(Y_validation,predictions))
print(confusion_matrix(Y_validation,predictions))
print(classification_report(Y_validation,predictions))
# Out:
# 0.9333333333333333
# [[ 7  0  0]
#  [ 0 10  2]
#  [ 0  0 11]]
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         7
# Iris-versicolor       1.00      0.83      0.91        12
#  Iris-virginica       0.85      1.00      0.92        11
#
#        accuracy                           0.93        30
#       macro avg       0.95      0.94      0.94        30
#    weighted avg       0.94      0.93      0.93        30
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
